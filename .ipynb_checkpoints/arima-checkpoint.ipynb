# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('./dataset.csv')

# %%
sns.lineplot(data=df, x='Период_Начало нед', y='KPI данные понедельно АлфаРМ_Продажи, рубли')
# Out:
# <Axes: xlabel='Период_Начало нед', ylabel='KPI данные понедельно АлфаРМ_Продажи, рубли'>

# %%
import statsmodels.api as sm

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

df['статистика заболеваемости_Статистика заболеваемости'] = scaler.fit_transform(df[['статистика заболеваемости_Статистика заболеваемости']])
df['статистика заболеваемости_Статистика заболеваемости']
# Out:
# 0     -0.835837
# 1     -0.179470
# 2      0.238837
# 3      0.667346
# 4      1.262497
#          ...
# 309         NaN
# 310         NaN
# 311         NaN
# 312         NaN
# 313         NaN
# Name: статистика заболеваемости_Статистика заболеваемости, Length: 314, dtype: float64

# %% [markdown]
# ###

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
pd.options.display.float_format = '{:.2f}'.format

from itertools import combinations
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA as ARIMA
import statsmodels.api as sm
import statsmodels.tsa.api as smt

# %%
df_train_val = df.iloc[:244,:]
df_train_val
# Out:
#      Период_год  Период_неделя    Период_Начало нед  \
# 0          2019              1  2018-12-31 00:00:00
# 1          2019              2  2019-01-07 00:00:00
# 2          2019              3  2019-01-14 00:00:00
# 3          2019              4  2019-01-21 00:00:00
# 4          2019              5  2019-01-28 00:00:00
# ..          ...            ...                  ...
# 239        2023             31  2023-07-31 00:00:00
# 240        2023             32  2023-08-07 00:00:00
# 241        2023             33  2023-08-14 00:00:00
# 242        2023             34  2023-08-21 00:00:00
# 243        2023             35  2023-08-28 00:00:00
#
#      KPI данные понедельно АлфаРМ_Продажи, рубли  \
# 0                                    41535567.34
# 1                                    51222286.23
# 2                                    57127348.91
# 3                                    63040990.94
# 4                                    67336888.87
# ..                                           ...
# 239                                  56931505.06
# 240                                  59881512.89
# 241                                  61112178.46
# 242                                  61594925.03
# 243                                  63106681.95
#
#      KPI данные понедельно АлфаРМ_Продажи, упаковки  \
# 0                                         114621.15
# 1                                         141523.20
# 2                                         157926.30
# 3                                         173746.65
# 4                                         185551.80
# ..                                              ...
# 239                                       110088.30
# 240                                       115345.65
# 241                                       117761.70
# 242                                       118356.00
# 243                                       120437.10
#
#      KPIданные помесячно АлфаРМ_Продажи, рубли  \
# 0                                 533280434.80
# 1                                 533280434.80
# 2                                 533280434.80
# 3                                 533280434.80
# 4                                 533280434.80
# ..                                         ...
# 239                               415482902.60
# 240                               453475648.10
# 241                               453475648.10
# 242                               453475648.10
# 243                               453475648.10
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор 0.01 % 150 мл N1, руб  \
# 0                                         357119029.90
# 1                                         357119029.90
# 2                                         357119029.90
# 3                                         357119029.90
# 4                                         357119029.90
# ..                                                 ...
# 239                                       243689995.89
# 240                                       266831900.02
# 241                                       266831900.02
# 242                                       266831900.02
# 243                                       266831900.02
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор  0.01 % 50 мл N1, руб  \
# 0                                         131122625.41
# 1                                         131122625.41
# 2                                         131122625.41
# 3                                         131122625.41
# 4                                         131122625.41
# ..                                                 ...
# 239                                       122713435.51
# 240                                       132395112.53
# 241                                       132395112.53
# 242                                       132395112.53
# 243                                       132395112.53
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор 0.01 % 500 мл N1, руб  \
# 0                                          19644473.04
# 1                                          19644473.04
# 2                                          19644473.04
# 3                                          19644473.04
# 4                                          19644473.04
# ..                                                 ...
# 239                                        29294571.05
# 240                                        32654557.10
# 241                                        32654557.10
# 242                                        32654557.10
# 243                                        32654557.10
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор 0.01 % 150 мл N1, упаковки  \
# 0                                            886424.70
# 1                                            886424.70
# 2                                            886424.70
# 3                                            886424.70
# 4                                            886424.70
# ..                                                 ...
# 239                                          412081.95
# 240                                          450227.40
# 241                                          450227.40
# 242                                          450227.40
# 243                                          450227.40
#
#      ...  Медиа (Конкурент 12)_ТВ Рег, рубли  Медиа (Конкурент 12)_Итого  \
# 0    ...                          7155663.63                 11834254.13
# 1    ...                          8348274.24                 13996532.16
# 2    ...                          8348274.24                 11466294.66
# 3    ...                          8348274.24                 10764632.16
# 4    ...                          8477038.25                 10984967.91
# ..   ...                                 ...                         ...
# 239  ...                                0.00                         NaN
# 240  ...                                0.00                         NaN
# 241  ...                                0.00                    69394.50
# 242  ...                                0.00                    78529.50
# 243  ...                                0.00                    31153.50
#
#      Медиа (Конкурент 13)_ТВ, trp(Ж 30-60 ВС)  \
# 0                                      207.90
# 1                                      317.47
# 2                                      192.82
# 3                                      138.37
# 4                                      286.98
# ..                                        ...
# 239                                      0.00
# 240                                      0.00
# 241                                      0.00
# 242                                      0.00
# 243                                      0.00
#
#      Медиа (Конкурент 13)_ТВ, охват 5+(Ж 30-60 ВС)  \
# 0                                            15.36
# 1                                            25.53
# 2                                            13.91
# 3                                             8.05
# 4                                            24.22
# ..                                             ...
# 239                                           0.00
# 240                                           0.00
# 241                                           0.00
# 242                                           0.00
# 243                                           0.00
#
#      Медиа (Конкурент 13)_ТВ, рубли  Медиа (Конкурент 13)_Диджитал, руб  \
# 0                 9085528.010322582                                0.00
# 1                 10599782.67870968                                0.00
# 2                 10599782.67870968                                0.00
# 3                 10599782.67870968                                0.00
# 4                12893092.405548388                                0.00
# ..                              ...                                 ...
# 239                               0                                0.00
# 240                               0                                0.00
# 241                               0                                0.00
# 242                               0                                0.00
# 243                               0                                0.00
#
#      Медиа (Конкурент 13)_ТВ спонсорство, рубли  \
# 0                                          0.00
# 1                                          0.00
# 2                                          0.00
# 3                                          0.00
# 4                                          0.00
# ..                                          ...
# 239                                        0.00
# 240                                        0.00
# 241                                        0.00
# 242                                        0.00
# 243                                        0.00
#
#      Медиа (Конкурент 13)_OOH, рубли Медиа (Конкурент 13)_Радио, рубли  \
# 0                               0.00                              0.00
# 1                               0.00                              0.00
# 2                               0.00                              0.00
# 3                               0.00                              0.00
# 4                               0.00                              0.00
# ..                               ...                               ...
# 239                             0.00                              0.00
# 240                             0.00                              0.00
# 241                             0.00                              0.00
# 242                             0.00                              0.00
# 243                             0.00                              0.00
#
#     Медиа (Конкурент 13)_Итого
# 0                   9085528.01
# 1                  10599782.68
# 2                  10599782.68
# 3                  10599782.68
# 4                  12893092.41
# ..                         ...
# 239                        NaN
# 240                        NaN
# 241                        NaN
# 242                        NaN
# 243                        NaN
#
# [244 rows x 147 columns]

# %%
sns.heatmap(df_train_val.isnull(),cmap = 'magma',cbar = False);

# %%
df_train_val['Месяц'] = pd.DatetimeIndex(pd.to_datetime(df_train_val['Период_Начало нед'])).month
df_train_val['День'] = pd.DatetimeIndex(pd.to_datetime(df_train_val['Период_Начало нед'])).day
# Out:
# /tmp/ipykernel_580772/982359196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_val['Месяц'] = pd.DatetimeIndex(pd.to_datetime(df_train_val['Период_Начало нед'])).month
# /tmp/ipykernel_580772/982359196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_val['День'] = pd.DatetimeIndex(pd.to_datetime(df_train_val['Период_Начало нед'])).day

# %%
df_train_val = df_train_val.drop(columns = ['Период_Начало нед'])

# %%
df_train_val
# Out:
#      Период_год  Период_неделя  KPI данные понедельно АлфаРМ_Продажи, рубли  \
# 0          2019              1                                  41535567.34
# 1          2019              2                                  51222286.23
# 2          2019              3                                  57127348.91
# 3          2019              4                                  63040990.94
# 4          2019              5                                  67336888.87
# ..          ...            ...                                          ...
# 239        2023             31                                  56931505.06
# 240        2023             32                                  59881512.89
# 241        2023             33                                  61112178.46
# 242        2023             34                                  61594925.03
# 243        2023             35                                  63106681.95
#
#      KPI данные понедельно АлфаРМ_Продажи, упаковки  \
# 0                                         114621.15
# 1                                         141523.20
# 2                                         157926.30
# 3                                         173746.65
# 4                                         185551.80
# ..                                              ...
# 239                                       110088.30
# 240                                       115345.65
# 241                                       117761.70
# 242                                       118356.00
# 243                                       120437.10
#
#      KPIданные помесячно АлфаРМ_Продажи, рубли  \
# 0                                 533280434.80
# 1                                 533280434.80
# 2                                 533280434.80
# 3                                 533280434.80
# 4                                 533280434.80
# ..                                         ...
# 239                               415482902.60
# 240                               453475648.10
# 241                               453475648.10
# 242                               453475648.10
# 243                               453475648.10
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор 0.01 % 150 мл N1, руб  \
# 0                                         357119029.90
# 1                                         357119029.90
# 2                                         357119029.90
# 3                                         357119029.90
# 4                                         357119029.90
# ..                                                 ...
# 239                                       243689995.89
# 240                                       266831900.02
# 241                                       266831900.02
# 242                                       266831900.02
# 243                                       266831900.02
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор  0.01 % 50 мл N1, руб  \
# 0                                         131122625.41
# 1                                         131122625.41
# 2                                         131122625.41
# 3                                         131122625.41
# 4                                         131122625.41
# ..                                                 ...
# 239                                       122713435.51
# 240                                       132395112.53
# 241                                       132395112.53
# 242                                       132395112.53
# 243                                       132395112.53
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор 0.01 % 500 мл N1, руб  \
# 0                                          19644473.04
# 1                                          19644473.04
# 2                                          19644473.04
# 3                                          19644473.04
# 4                                          19644473.04
# ..                                                 ...
# 239                                        29294571.05
# 240                                        32654557.10
# 241                                        32654557.10
# 242                                        32654557.10
# 243                                        32654557.10
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор 0.01 % 150 мл N1, упаковки  \
# 0                                            886424.70
# 1                                            886424.70
# 2                                            886424.70
# 3                                            886424.70
# 4                                            886424.70
# ..                                                 ...
# 239                                          412081.95
# 240                                          450227.40
# 241                                          450227.40
# 242                                          450227.40
# 243                                          450227.40
#
#      KPI данные помесячно АлфаРМ (по SKU)_раствор  0.01 % 50 мл N1, упаковки  \
# 0                                            461401.50
# 1                                            461401.50
# 2                                            461401.50
# 3                                            461401.50
# 4                                            461401.50
# ..                                                 ...
# 239                                          318306.45
# 240                                          340625.25
# 241                                          340625.25
# 242                                          340625.25
# 243                                          340625.25
#
#      ...  Медиа (Конкурент 13)_ТВ, trp(Ж 30-60 ВС)  \
# 0    ...                                    207.90
# 1    ...                                    317.47
# 2    ...                                    192.82
# 3    ...                                    138.37
# 4    ...                                    286.98
# ..   ...                                       ...
# 239  ...                                      0.00
# 240  ...                                      0.00
# 241  ...                                      0.00
# 242  ...                                      0.00
# 243  ...                                      0.00
#
#      Медиа (Конкурент 13)_ТВ, охват 5+(Ж 30-60 ВС)  \
# 0                                            15.36
# 1                                            25.53
# 2                                            13.91
# 3                                             8.05
# 4                                            24.22
# ..                                             ...
# 239                                           0.00
# 240                                           0.00
# 241                                           0.00
# 242                                           0.00
# 243                                           0.00
#
#      Медиа (Конкурент 13)_ТВ, рубли  Медиа (Конкурент 13)_Диджитал, руб  \
# 0                 9085528.010322582                                0.00
# 1                 10599782.67870968                                0.00
# 2                 10599782.67870968                                0.00
# 3                 10599782.67870968                                0.00
# 4                12893092.405548388                                0.00
# ..                              ...                                 ...
# 239                               0                                0.00
# 240                               0                                0.00
# 241                               0                                0.00
# 242                               0                                0.00
# 243                               0                                0.00
#
#      Медиа (Конкурент 13)_ТВ спонсорство, рубли  \
# 0                                          0.00
# 1                                          0.00
# 2                                          0.00
# 3                                          0.00
# 4                                          0.00
# ..                                          ...
# 239                                        0.00
# 240                                        0.00
# 241                                        0.00
# 242                                        0.00
# 243                                        0.00
#
#      Медиа (Конкурент 13)_OOH, рубли  Медиа (Конкурент 13)_Радио, рубли  \
# 0                               0.00                               0.00
# 1                               0.00                               0.00
# 2                               0.00                               0.00
# 3                               0.00                               0.00
# 4                               0.00                               0.00
# ..                               ...                                ...
# 239                             0.00                               0.00
# 240                             0.00                               0.00
# 241                             0.00                               0.00
# 242                             0.00                               0.00
# 243                             0.00                               0.00
#
#     Медиа (Конкурент 13)_Итого Месяц  День
# 0                   9085528.01    12    31
# 1                  10599782.68     1     7
# 2                  10599782.68     1    14
# 3                  10599782.68     1    21
# 4                  12893092.41     1    28
# ..                         ...   ...   ...
# 239                        NaN     7    31
# 240                        NaN     8     7
# 241                        NaN     8    14
# 242                        NaN     8    21
# 243                        NaN     8    28
#
# [244 rows x 148 columns]

# %%
def test_stationarity(timeseries):
    #Determing rolling statistics
    MA = timeseries.rolling(window=12).mean()
    MSTD = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    plt.figure(figsize=(15,5))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(MA, color='red', label='Rolling Mean')
    std = plt.plot(MSTD, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (2, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()

# %%
plt.figure(figsize = (15,5))
df_train_val['KPI данные понедельно АлфаРМ_Продажи, рубли'].plot();

# %%
dec = sm.tsa.seasonal_decompose(df_train_val['KPI данные понедельно АлфаРМ_Продажи, рубли'],period = 52, model = 'multiplicative').plot()
plt.show()

# %%
test_stationarity(df_train_val['KPI данные понедельно АлфаРМ_Продажи, рубли'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.19
# p-value                         0.00
# #Lags Used                      3.00
# Number of Observations Used   240.00
# Critical Value (1%)            -3.46
# Critical Value (5%)            -2.87
# Critical Value (10%)           -2.57
# dtype: float64

# %%
# data_diff = df_train_val.diff()
# data_diff = data_diff.dropna()

# dec = sm.tsa.seasonal_decompose(data_diff,period = 12).plot()
# plt.show()

# %%
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  244
# Model:                 ARIMA(1, 1, 2)   Log Likelihood               -4283.842
# Date:                Sun, 14 Apr 2024   AIC                           8575.685
# Time:                        00:18:04   BIC                           8589.657
# Sample:                             0   HQIC                          8581.313
#                                 - 244
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7535      0.055     13.678      0.000       0.645       0.861
# ma.L1         -0.6024      0.063     -9.611      0.000      -0.725      -0.480
# ma.L2         -0.3684      0.049     -7.562      0.000      -0.464      -0.273
# sigma2      1.324e+14   1.05e-16   1.26e+30      0.000    1.32e+14    1.32e+14
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.73   Jarque-Bera (JB):             63630.14
# Prob(Q):                              0.39   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.11   Skew:                             6.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                        81.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.74e+45. Standard errors may be unstable.

# %%
threshold = 244
train = int(threshold * 0.3)

# %%
import numpy as np
df = pd.read_csv('./dataset.csv')
df.replace(' ', pd.NA, inplace=True)

df = df.apply(lambda x: pd.to_numeric(x, errors='ignore'))

numeric_columns = df.select_dtypes(include=['number'])

column_means = numeric_columns.mean()

df[numeric_columns.columns] = df[numeric_columns.columns].fillna(column_means)

col = [column for column in df.select_dtypes(include=['number']) if ('руб' in column.lower()) or ('итого' in column.lower())]
df[col] = df[col] / 10**8

col = [column for column in df.columns if 'конкурент' not in column.lower()]
new_df = df[col]
X, y = new_df.drop(columns=['KPI данные понедельно АлфаРМ_Продажи, рубли']), new_df['KPI данные понедельно АлфаРМ_Продажи, рубли']
X = X[X.columns[3:]]

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df_scaled = pd.DataFrame(ss.fit_transform(X), columns=X.columns)

train_X, train_y  = df_scaled[:train], y[:train]
test_X, test_y = df_scaled[train:], y[train:]
train_X['target'] = train_y
test_X['target'] = test_y
# Out:
# /tmp/ipykernel_90257/1871596717.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(lambda x: pd.to_numeric(x, errors='ignore'))
# /tmp/ipykernel_90257/1871596717.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_X['target'] = train_y
# /tmp/ipykernel_90257/1871596717.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['target'] = test_y

# %%
import statsmodels as sm


model = sm.tsa.arima.model.ARIMA(np.asarray(train_X['target']), order=(2,1,2))

model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   73
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                  23.959
# Date:                Sun, 14 Apr 2024   AIC                            -37.919
# Time:                        00:27:54   BIC                            -26.535
# Sample:                             0   HQIC                           -33.387
#                                  - 73
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9961      0.388      2.565      0.010       0.235       1.757
# ar.L2         -0.3448      0.308     -1.118      0.263      -0.949       0.259
# ma.L1         -0.8717      0.433     -2.015      0.044      -1.719      -0.024
# ma.L2         -0.0753      0.461     -0.163      0.870      -0.979       0.828
# sigma2         0.0295      0.002     17.620      0.000       0.026       0.033
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              5509.46
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              47.08   Skew:                             5.73
# Prob(H) (two-sided):                  0.00   Kurtosis:                        44.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
test.iloc[0]
# Out:
# 0.39530685159

# %%
train, test = train_X['target'][:], test_X['target'][:]

history = [x for x in train]
predictions = []

for t in range(len(test)):
    
    model = sm.tsa.arima.model.ARIMA(history, order=(2,1,2))
    model_fit = model.fit()
    
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(float(yhat))
    
    obs = test.iloc[t]
    history.append(obs)
    
    print('predicted = %f, expected = %f' % (yhat, obs))
# Out:
# [0.41535567339, 0.51222286227, 0.5712734890799998, 0.6304099093950002, 0.6733688886750002, 0.7042447995450001, 0.6862118493300007, 0.6174298270350004, 0.6166924168650001, 0.5471173121400006, 0.6037083418800002, 0.5771104793999998, 0.5498465126700004, 0.5395710097050005, 0.5446567357350004, 0.5610219306300003, 0.5352251476949996, 0.4959558316650007, 0.42497605751999995, 0.45385737547499994, 0.45787518136499994, 0.4613027430899997, 0.4737392306849999, 0.4758037855199999, 0.468513195045, 0.46248933517499985, 0.45910321065, 0.46879679700000015, 0.46447160056499964, 0.45545038990500075, 0.45828373647000015, 0.46180807480500013, 0.48863738112000027, 0.4726975900499999, 0.49555107105000057, 0.5198273799600003, 0.6887307465150003, 0.7050538877550001, 0.6513231819150003, 0.6000602581050006, 0.596377962705, 0.579307623615, 0.5557682500649996, 0.5299217227499997, 0.5036787820049999, 0.5469827422499995, 0.5605593338099999, 0.5803993802249994, 0.5684795596199997, 0.5925953347649997, 0.5942022454199998, 0.6147669771600004, 0.572546976855, 0.5738415433800003, 0.6116174450399996, 0.6840214692150006, 0.7893001071900005, 0.8196327649650009, 0.7990199804999996, 0.727666696365, 0.712634653815, 0.753217996125, 0.9829740816000004, 2.2689087566249997, 2.012493782880002, 1.389758708100001, 0.7086696577800006, 0.6401491449149996, 0.5589597836549998, 0.4886552070750002, 0.4348736044799996, 0.4492028496900002, 0.4116868938]
# predicted = 0.490865, expected = 0.395307
# predicted = 0.476688, expected = 0.413001
# predicted = 0.493664, expected = 0.406870
# predicted = 0.469446, expected = 0.469591
# predicted = 0.541692, expected = 0.463716
# predicted = 0.501456, expected = 0.505219
# predicted = 0.552970, expected = 0.542227
# predicted = 0.574424, expected = 0.590787
# predicted = 0.615074, expected = 0.618836
# predicted = 0.626887, expected = 0.633437
# predicted = 0.633297, expected = 0.653281
# predicted = 0.650798, expected = 0.663204
# predicted = 0.654114, expected = 0.641457
# predicted = 0.626034, expected = 0.630848
# predicted = 0.623991, expected = 0.666030
# predicted = 0.667523, expected = 0.854484
# predicted = 0.867185, expected = 0.888212
# predicted = 0.825875, expected = 0.808376
# /home/user/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted = 0.731503, expected = 0.785212
# predicted = 0.743130, expected = 0.802008
# /home/user/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted = 0.769795, expected = 0.809442
# predicted = 0.771650, expected = 0.799698
# predicted = 0.759743, expected = 0.780712
# predicted = 0.744051, expected = 0.721855
# predicted = 0.685590, expected = 0.731678
# predicted = 0.722770, expected = 0.697000
# predicted = 0.676053, expected = 0.692471
# predicted = 0.687456, expected = 0.717480
# predicted = 0.716267, expected = 0.734030
# predicted = 0.724429, expected = 0.729764
# predicted = 0.714035, expected = 0.721059
# predicted = 0.707185, expected = 0.610885
# predicted = 0.585017, expected = 0.569984
# predicted = 0.586199, expected = 0.599366
# predicted = 0.631045, expected = 0.571452
# predicted = 0.583502, expected = 0.602968
# predicted = 0.632852, expected = 0.645118
# predicted = 0.664611, expected = 0.675122
# predicted = 0.681780, expected = 0.679778
# predicted = 0.675866, expected = 0.581534
# predicted = 0.563394, expected = 0.599698
# predicted = 0.627014, expected = 0.605482
# predicted = 0.619573, expected = 0.640186
# predicted = 0.657676, expected = 0.597871
# predicted = 0.594255, expected = 0.583336
# predicted = 0.597755, expected = 0.606871
# predicted = 0.627732, expected = 0.638577
# predicted = 0.652510, expected = 0.629963
# predicted = 0.630007, expected = 0.615319
# predicted = 0.618594, expected = 0.557039
# predicted = 0.557989, expected = 0.520582
# predicted = 0.540784, expected = 0.538181
# predicted = 0.572739, expected = 0.554233
# predicted = 0.580809, expected = 0.586941
# predicted = 0.611514, expected = 0.628818
# predicted = 0.645017, expected = 0.644124
# predicted = 0.645622, expected = 0.655201
# predicted = 0.653557, expected = 0.720499
# predicted = 0.723196, expected = 0.749699
# predicted = 0.728596, expected = 0.745928
# predicted = 0.715622, expected = 0.733464
# predicted = 0.704860, expected = 0.715552
# predicted = 0.690115, expected = 0.726502
# predicted = 0.710130, expected = 0.740639
# predicted = 0.720866, expected = 0.725990
# predicted = 0.699246, expected = 0.718576
# predicted = 0.698402, expected = 0.766211
# predicted = 0.755257, expected = 0.972278
# predicted = 0.970183, expected = 1.085415
# predicted = 1.014530, expected = 0.963928
# predicted = 0.837012, expected = 0.899790
# predicted = 0.826729, expected = 0.922609
# predicted = 0.876546, expected = 0.948101
# predicted = 0.895201, expected = 0.931682
# predicted = 0.868947, expected = 0.901054
# predicted = 0.844512, expected = 0.839358
# predicted = 0.787109, expected = 0.834068
# predicted = 0.808560, expected = 0.859151
# predicted = 0.837568, expected = 0.919298
# predicted = 0.898201, expected = 0.980412
# predicted = 0.946347, expected = 0.981966
# predicted = 0.926695, expected = 0.963501
# predicted = 0.910817, expected = 0.886750
# predicted = 0.830835, expected = 0.787323
# predicted = 0.749293, expected = 0.702737
# predicted = 0.690715, expected = 0.781864
# predicted = 0.816725, expected = 1.020057
# predicted = 1.058366, expected = 1.391932
# predicted = 1.408073, expected = 1.419251
# predicted = 1.276112, expected = 1.164235
# predicted = 0.981734, expected = 0.958464
# predicted = 0.868811, expected = 0.735968
# predicted = 0.685837, expected = 0.829182
# predicted = 0.905869, expected = 0.715700
# predicted = 0.701440, expected = 0.704237
# predicted = 0.748258, expected = 0.628474
# predicted = 0.651071, expected = 0.576074
# predicted = 0.621107, expected = 0.560841
# predicted = 0.619653, expected = 0.571336
# predicted = 0.633280, expected = 0.553974
# predicted = 0.603220, expected = 0.579824
# predicted = 0.640638, expected = 0.542325
# predicted = 0.579430, expected = 0.499157
# predicted = 0.544957, expected = 0.536505
# predicted = 0.605389, expected = 0.533805
# predicted = 0.579568, expected = 0.548858
# predicted = 0.599925, expected = 0.577145
# predicted = 0.624508, expected = 0.557737
# predicted = 0.587707, expected = 0.546045
# predicted = 0.583506, expected = 0.554242
# predicted = 0.596033, expected = 0.584085
# predicted = 0.626151, expected = 0.619721
# predicted = 0.654394, expected = 0.627759
# predicted = 0.648520, expected = 0.639688
# predicted = 0.660647, expected = 0.720664
# predicted = 0.751381, expected = 0.791827
# predicted = 0.798762, expected = 0.837834
# predicted = 0.825877, expected = 0.826625
# predicted = 0.795455, expected = 0.830105
# predicted = 0.808133, expected = 0.946097
# predicted = 0.944683, expected = 1.048875
# predicted = 1.014865, expected = 0.938959
# predicted = 0.843333, expected = 0.813291
# predicted = 0.752624, expected = 0.779301
# predicted = 0.763783, expected = 0.775643
# predicted = 0.768034, expected = 0.748863
# predicted = 0.736564, expected = 0.722003
# predicted = 0.717197, expected = 0.681509
# predicted = 0.679459, expected = 0.703000
# predicted = 0.722672, expected = 0.749760
# predicted = 0.765423, expected = 0.785905
# predicted = 0.788315, expected = 0.868355
# predicted = 0.873224, expected = 0.966784
# predicted = 0.954781, expected = 1.004678
# predicted = 0.959946, expected = 0.927931
# predicted = 0.856830, expected = 0.810862
# predicted = 0.755783, expected = 0.667150
# predicted = 0.633639, expected = 0.664669
# predicted = 0.692815, expected = 0.647189
# predicted = 0.662935, expected = 0.678608
# predicted = 0.709912, expected = 0.719599
# predicted = 0.742122, expected = 0.736623
# predicted = 0.744942, expected = 0.743998
# predicted = 0.748038, expected = 0.649462
# predicted = 0.631410, expected = 0.676795
# predicted = 0.710130, expected = 0.611145
# predicted = 0.610801, expected = 0.657744
# predicted = 0.700450, expected = 0.629670
# predicted = 0.639114, expected = 0.590693
# predicted = 0.608967, expected = 0.600880
# predicted = 0.636544, expected = 0.601665
# predicted = 0.629565, expected = 0.611599
# predicted = 0.641456, expected = 0.598136
# predicted = 0.619848, expected = 0.566979
# predicted = 0.588890, expected = 0.523693
# predicted = 0.549846, expected = 0.569663
# predicted = 0.622791, expected = 0.551153
# predicted = 0.575104, expected = 0.561334
# predicted = 0.598908, expected = 0.563759
# predicted = 0.594398, expected = 0.550151
# predicted = 0.577101, expected = 0.556180
# predicted = 0.590051, expected = 0.534262
# predicted = 0.559027, expected = 0.569868
# predicted = 0.612060, expected = 0.568123
# predicted = 0.590708, expected = 0.553975
# predicted = 0.576493, expected = 0.559035
# predicted = 0.588009, expected = 0.569315
# predicted = 0.596335, expected = 0.598815
# predicted = 0.626900, expected = 0.611122
# predicted = 0.627863, expected = 0.615949
# predicted = 0.629407, expected = 0.631067
# predicted = 0.645602, expected = 0.679789
# predicted = 0.697342, expected = 0.679789
# predicted = 0.675186, expected = 0.679789
# predicted = 0.678545, expected = 0.679789
# predicted = 0.678125, expected = 0.679789
# predicted = 0.678259, expected = 0.679789
# predicted = 0.678306, expected = 0.679789
# predicted = 0.678368, expected = 0.679789
# predicted = 0.678428, expected = 0.679789
# predicted = 0.678471, expected = 0.679789
# predicted = 0.678517, expected = 0.679789
# predicted = 0.678562, expected = 0.679789
# predicted = 0.678613, expected = 0.679789
# predicted = 0.678648, expected = 0.679789
# predicted = 0.678690, expected = 0.679789
# predicted = 0.678728, expected = 0.679789
# predicted = 0.678765, expected = 0.679789
# predicted = 0.678801, expected = 0.679789
# predicted = 0.678835, expected = 0.679789
# predicted = 0.678869, expected = 0.679789
# predicted = 0.678896, expected = 0.679789
# predicted = 0.678923, expected = 0.679789
# predicted = 0.678958, expected = 0.679789
# predicted = 0.678984, expected = 0.679789
# predicted = 0.678991, expected = 0.679789
# predicted = 0.679038, expected = 0.679789
# predicted = 0.679062, expected = 0.679789
# predicted = 0.679086, expected = 0.679789
# predicted = 0.679109, expected = 0.679789
# predicted = 0.679132, expected = 0.679789
# predicted = 0.679152, expected = 0.679789
# predicted = 0.679173, expected = 0.679789
# predicted = 0.679193, expected = 0.679789
# predicted = 0.679212, expected = 0.679789
# predicted = 0.679231, expected = 0.679789
# predicted = 0.679248, expected = 0.679789
# predicted = 0.679265, expected = 0.679789
# predicted = 0.679282, expected = 0.679789
# predicted = 0.679298, expected = 0.679789
# predicted = 0.679314, expected = 0.679789
# predicted = 0.679329, expected = 0.679789
# /home/user/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# predicted = 0.679344, expected = 0.679789
# predicted = 0.679357, expected = 0.679789
# predicted = 0.679371, expected = 0.679789
# predicted = 0.679384, expected = 0.679789
# predicted = 0.679397, expected = 0.679789
# predicted = 0.679409, expected = 0.679789
# predicted = 0.679421, expected = 0.679789
# predicted = 0.679433, expected = 0.679789
# predicted = 0.679444, expected = 0.679789
# predicted = 0.679454, expected = 0.679789
# predicted = 0.679465, expected = 0.679789
# predicted = 0.679475, expected = 0.679789
# predicted = 0.679485, expected = 0.679789
# predicted = 0.679494, expected = 0.679789
# predicted = 0.679503, expected = 0.679789
# predicted = 0.679512, expected = 0.679789
# predicted = 0.679521, expected = 0.679789
# predicted = 0.679529, expected = 0.679789
# predicted = 0.679537, expected = 0.679789
# predicted = 0.679545, expected = 0.679789
# predicted = 0.679553, expected = 0.679789
# predicted = 0.679560, expected = 0.679789
# predicted = 0.679568, expected = 0.679789
# predicted = 0.679574, expected = 0.679789
# predicted = 0.679581, expected = 0.679789
# predicted = 0.679588, expected = 0.679789
# predicted = 0.679594, expected = 0.679789
# predicted = 0.679601, expected = 0.679789
# predicted = 0.679605, expected = 0.679789

# %%
predictions_series = pd.Series(predictions, index = test.index)
fig,ax = plt.subplots(nrows = 1,ncols = 1,figsize = (15,5))

plt.subplot(1,1,1)
plt.plot(pd.concat([train, test], ignore_index=True), label = 'Expected Values')
plt.plot(np.exp(predictions_series),label = 'Predicted Values');
plt.legend(loc="upper left")
plt.show()

# %%
# !pip install sktime[all_extras]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sktime[all_extras] in /home/user/.local/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (1.12.0)
# Requirement already satisfied: packaging in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (23.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (1.26.4)
# Requirement already satisfied: scikit-learn<1.5.0,>=0.24 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (1.4.1.post1)
# Requirement already satisfied: scikit-base<0.8.0 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (0.7.5)
# Requirement already satisfied: pandas<2.3.0,>=1.1 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (2.2.1)
# Collecting skpro<2.3.0,>=2
#   Downloading skpro-2.2.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 KB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting kotsu>=0.3.1
#   Downloading kotsu-0.3.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: seaborn>=0.11 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (0.13.2)
# Collecting hmmlearn>=0.2.7
#   Downloading hmmlearn-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 KB 9.3 MB/s eta 0:00:00
# Collecting statsforecast<1.8.0,>=1.0.0
#   Downloading statsforecast-1.7.4-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.8/121.8 KB 8.8 MB/s eta 0:00:00
# Collecting pycatch22<0.4.4
#   Downloading pycatch22-0.4.2.tar.gz (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 KB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package pycatch22 produced metadata for project name unknown. Fix your #egg=pycatch22 fragments.
# Discarding https://files.pythonhosted.org/packages/f4/7f/e0083a771ecefe10a0fd7b37d9be15adceec16648ed1a81625ade312d23c/pycatch22-0.4.2.tar.gz#sha256=162bd9774a326993c564120221e779fb6e578139e9fb73ed6066a3137e61c3ad (from https://pypi.org/simple/pycatch22/): Requested unknown from https://files.pythonhosted.org/packages/f4/7f/e0083a771ecefe10a0fd7b37d9be15adceec16648ed1a81625ade312d23c/pycatch22-0.4.2.tar.gz#sha256=162bd9774a326993c564120221e779fb6e578139e9fb73ed6066a3137e61c3ad (from sktime) has inconsistent name: filename has 'pycatch22', but metadata has 'unknown'
#   Downloading pycatch22-0.4.1.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 6.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Discarding https://files.pythonhosted.org/packages/f8/d9/5beac06dce706d96c8b3a5f12352af61e323399af71f27556804b990ad25/pycatch22-0.4.1.tar.gz#sha256=2ef4895b5e8120abf2ecb0dcea49a65e3d03b3e6b3a1b905928b4b1856be9ec7 (from https://pypi.org/simple/pycatch22/): Requested pycatch22<0.4.4 from https://files.pythonhosted.org/packages/f8/d9/5beac06dce706d96c8b3a5f12352af61e323399af71f27556804b990ad25/pycatch22-0.4.1.tar.gz#sha256=2ef4895b5e8120abf2ecb0dcea49a65e3d03b3e6b3a1b905928b4b1856be9ec7 (from sktime) has inconsistent version: filename has '0.4.1', but metadata has '0.0.0'
#   Downloading pycatch22-0.2.0.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 KB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package pycatch22 produced metadata for project name unknown. Fix your #egg=pycatch22 fragments.
# Discarding https://files.pythonhosted.org/packages/bb/e1/a42d66cea3f7ad49381ce1b770af76918713bb33378469643d1776b2919a/pycatch22-0.2.0.tar.gz#sha256=4c3b7803cf5ed2892fb46ff77f8c4a750e32c44121aa6853019a05fedc393b45 (from https://pypi.org/simple/pycatch22/): Requested unknown from https://files.pythonhosted.org/packages/bb/e1/a42d66cea3f7ad49381ce1b770af76918713bb33378469643d1776b2919a/pycatch22-0.2.0.tar.gz#sha256=4c3b7803cf5ed2892fb46ff77f8c4a750e32c44121aa6853019a05fedc393b45 (from sktime) has inconsistent name: filename has 'pycatch22', but metadata has 'unknown'
# Collecting sktime[all_extras]
#   Downloading sktime-0.27.1-py3-none-any.whl (21.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting pandas<2.2.0,>=1.1
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting sktime[all_extras]
#   Downloading sktime-0.27.0-py3-none-any.whl (21.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 5.6 MB/s eta 0:00:0000:0100:01
#   Downloading sktime-0.26.1-py3-none-any.whl (21.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 7.6 MB/s eta 0:00:0000:0100:01
#   Downloading sktime-0.26.0-py3-none-any.whl (21.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 8.5 MB/s eta 0:00:0000:0100:01
#   Downloading sktime-0.25.1-py3-none-any.whl (21.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Collecting scikit-learn<1.4.0,>=0.24
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 8.5 MB/s eta 0:00:0000:0100:01
# Collecting sktime[all_extras]
#   Downloading sktime-0.25.0-py3-none-any.whl (21.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting scikit-base<0.7.0
#   Downloading scikit_base-0.6.2-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 KB 7.6 MB/s eta 0:00:00
# Collecting arch<6.3.0,>=5.6
#   Downloading arch-6.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.7/981.7 KB 7.1 MB/s eta 0:00:00a 0:00:01
# Collecting sktime[all_extras]
#   Downloading sktime-0.24.2-py3-none-any.whl (21.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 5.9 MB/s eta 0:00:0000:0100:01
#   Downloading sktime-0.24.1-py3-none-any.whl (20.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 6.1 MB/s eta 0:00:0000:0100:01
#   Downloading sktime-0.24.0-py3-none-any.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 6.2 MB/s eta 0:00:0000:0100:01
# Collecting filterpy>=1.4.5
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting statsforecast<1.7.0,>=0.5.2
#   Downloading statsforecast-1.6.0-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 KB 6.1 MB/s eta 0:00:00
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting dash!=2.9.0
#   Downloading dash-2.16.1-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 7.0 MB/s eta 0:00:0000:010:01
# Collecting h5py
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 7.4 MB/s eta 0:00:0000:0100:01
# Collecting cloudpickle
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in /home/user/.local/lib/python3.10/site-packages (from sktime[all_extras]) (0.14.1)
# Collecting pycatch22
#   Downloading pycatch22-0.4.4.tar.gz (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 KB 6.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.7 MB/s eta 0:00:0000:0100:02
# Collecting gluonts>=0.9.0
#   Downloading gluonts-0.14.4-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 4.3 MB/s eta 0:00:00:00:0100:01
# Collecting Werkzeug<3.1
#   Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 KB 4.3 MB/s eta 0:00:0000:01
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/user/.local/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (4.10.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/user/.local/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (5.20.0)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: requests in /home/user/.local/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (2.31.0)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from dash!=2.9.0->sktime[all_extras]) (4.6.4)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from dash!=2.9.0->sktime[all_extras]) (59.6.0)
# Requirement already satisfied: nest-asyncio in /home/user/.local/lib/python3.10/site-packages (from dash!=2.9.0->sktime[all_extras]) (1.6.0)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting Flask<3.1,>=1.0.4
#   Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 KB 8.1 MB/s eta 0:00:00
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 KB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.7 in /home/user/.local/lib/python3.10/site-packages (from gluonts>=0.9.0->sktime[all_extras]) (2.6.4)
# Requirement already satisfied: toolz~=0.10 in /home/user/.local/lib/python3.10/site-packages (from gluonts>=0.9.0->sktime[all_extras]) (0.12.1)
# Requirement already satisfied: tqdm~=4.23 in /home/user/.local/lib/python3.10/site-packages (from gluonts>=0.9.0->sktime[all_extras]) (4.66.2)
# Requirement already satisfied: pillow>=8 in /home/user/.local/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/.local/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3.2->sktime[all_extras]) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/.local/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /home/user/.local/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/.local/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/user/.local/lib/python3.10/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.4.5)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/user/.local/lib/python3.10/site-packages (from numba>=0.53->sktime[all_extras]) (0.42.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/user/.local/lib/python3.10/site-packages (from pandas<2.1.0,>=1.1.0->sktime[all_extras]) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<2.1.0,>=1.1.0->sktime[all_extras]) (2022.1)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-3.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 8.5 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: joblib>=0.11 in /home/user/.local/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (1.3.2)
# Requirement already satisfied: urllib3 in /home/user/.local/lib/python3.10/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (2.2.1)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.2.2-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 KB 9.4 MB/s eta 0:00:00
# Collecting holidays>=0.25
#   Downloading holidays-0.46-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.7 MB/s eta 0:00:00:00:0100:01
# Collecting importlib-resources
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from pyod>=0.8.0->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/user/.local/lib/python3.10/site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime[all_extras]) (3.3.0)
# Collecting fugue>=0.8.1
#   Downloading fugue-0.8.7-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.8/279.8 KB 7.0 MB/s eta 0:00:0000:01
# Collecting coreforecast>=0.0.7
#   Downloading coreforecast-0.0.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 KB 7.6 MB/s eta 0:00:00
# Collecting utilsforecast>=0.0.24
#   Downloading utilsforecast-0.1.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 KB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.4 in /home/user/.local/lib/python3.10/site-packages (from statsmodels>=0.12.1->sktime[all_extras]) (0.5.6)
# Collecting partd>=1.2.0
#   Downloading partd-1.4.1-py3-none-any.whl (18 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/user/.local/lib/python3.10/site-packages (from dask->sktime[all_extras]) (2024.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from dask->sktime[all_extras]) (5.4.1)
# Collecting click>=8.1
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from mne->sktime[all_extras]) (3.0.3)
# Collecting pooch>=1.5
#   Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 KB 4.0 MB/s eta 0:00:00
# Collecting lazy-loader>=0.3
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: decorator in /home/user/.local/lib/python3.10/site-packages (from mne->sktime[all_extras]) (5.1.1)
# Collecting pyaml>=16.9
#   Downloading pyaml-23.12.0-py3-none-any.whl (23 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 KB 5.3 MB/s eta 0:00:00
# Collecting ml-dtypes~=0.3.1
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.6 MB/s eta 0:00:00:00:0100:01
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 6.6 MB/s eta 0:00:00:00:0100:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 10.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: termcolor>=1.1.0 in /home/user/.local/lib/python3.10/site-packages (from tensorflow->sktime[all_extras]) (2.4.0)
# Collecting tensorboard<2.17,>=2.16
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 11.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/user/.local/lib/python3.10/site-packages (from tensorflow->sktime[all_extras]) (1.62.1)
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/user/.local/lib/python3.10/site-packages (from tensorflow->sktime[all_extras]) (4.25.3)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 8.5 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 7.8 MB/s eta 0:00:00
# Collecting keras>=3.0.0
#   Downloading keras-3.2.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow->sktime[all_extras]) (0.37.1)
# Collecting stanio<2.0.0,>=0.4.0
#   Downloading stanio-0.5.0-py3-none-any.whl (8.0 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/user/.local/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash!=2.9.0->sktime[all_extras]) (2.1.2)
# Collecting jinja2
#   Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 KB 8.6 MB/s eta 0:00:00
# Collecting qpd>=0.4.4
#   Downloading qpd-0.4.4-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 KB 9.0 MB/s eta 0:00:00
# Collecting triad>=0.9.3
#   Downloading triad-0.9.6-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 KB 6.4 MB/s eta 0:00:00
# Collecting fugue-sql-antlr>=0.1.6
#   Downloading fugue-sql-antlr-0.2.0.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 KB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sqlglot
#   Downloading sqlglot-23.10.0-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 KB 10.4 MB/s eta 0:00:0000:01
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata->dash!=2.9.0->sktime[all_extras]) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->mne->sktime[all_extras]) (2.0.1)
# Requirement already satisfied: rich in /home/user/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow->sktime[all_extras]) (13.7.1)
# Collecting optree
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 KB 9.4 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /home/user/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash!=2.9.0->sktime[all_extras]) (8.2.3)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/user/.local/lib/python3.10/site-packages (from pooch>=1.5->mne->sktime[all_extras]) (4.2.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/user/.local/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts>=0.9.0->sktime[all_extras]) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/user/.local/lib/python3.10/site-packages (from pydantic<3,>=1.7->gluonts>=0.9.0->sktime[all_extras]) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->dash!=2.9.0->sktime[all_extras]) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->dash!=2.9.0->sktime[all_extras]) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/.local/lib/python3.10/site-packages (from requests->dash!=2.9.0->sktime[all_extras]) (3.3.2)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 KB 8.4 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 11.0 MB/s eta 0:00:0000:0100:01
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting antlr4-python3-runtime<4.12
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in /home/user/.local/lib/python3.10/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast<1.8.0,>=1.0.0->sktime[all_extras]) (15.0.1)
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 KB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/user/.local/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow->sktime[all_extras]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/user/.local/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow->sktime[all_extras]) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/user/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow->sktime[all_extras]) (0.1.2)
# Collecting appdirs~=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: filterpy, pyod, keras-self-attention, fugue-sql-antlr
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=505d2bca88be718d780fb0fe43b7c662abca630709d7abe848d28adeeb759d63
#   Stored in directory: /home/user/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.1.3-py3-none-any.whl size=190273 sha256=7dbd00102d614a7a5d759095685f858cd6ae3ea2346e3aa2dae06e3eb44c4d36
#   Stored in directory: /home/user/.cache/pip/wheels/05/f8/db/124d43bec122d6ec0ab3713fadfe25ebed8af52ec561682b4e
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=4aedb9b5f1c398e423520c6438eec61ce42dace9c0c44f0ddd892a2c3658e66d
#   Stored in directory: /home/user/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.2.0-py3-none-any.whl size=158222 sha256=58c03b87c6477439200df8f62459f994f390ebababc059ac5d83323bd4e3b702
#   Stored in directory: /home/user/.cache/pip/wheels/5a/b5/4e/216953a1c711da55de29ed7ecf158b4a5bf32ef93d69ad66dd
# Successfully built filterpy pyod keras-self-attention fugue-sql-antlr
# Installing collected packages: namex, libclang, flatbuffers, dash-table, dash-html-components, dash-core-components, appdirs, antlr4-python3-runtime, wrapt, tensorflow-io-gcs-filesystem, tensorboard-data-server, sqlglot, scikit-base, retrying, pyaml, optree, numpy, MarkupSafe, markdown, locket, lazy-loader, importlib-resources, importlib-metadata, google-pasta, gast, fs, Cython, cloudpickle, click, blinker, astunparse, absl-py, Werkzeug, stanio, pooch, partd, pandas, opt-einsum, ml-dtypes, keras-self-attention, jinja2, holidays, h5py, deprecated, coreforecast, xarray, utilsforecast, triad, tensorboard, stumpy, seasonal, scikit-learn, pykalman, kotsu, keras, gluonts, Flask, dtw-python, dask, cmdstanpy, tslearn, tsfresh, tensorflow, sktime, scikit-optimize, pyod, prophet, pmdarima, mne, hmmlearn, fugue-sql-antlr, filterpy, dash, adagio, tbats, scikit-posthocs, qpd, fugue, statsforecast
#   Attempting uninstall: scikit-base
#     Found existing installation: scikit-base 0.7.5
#     Uninstalling scikit-base-0.7.5:
#       Successfully uninstalled scikit-base-0.7.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.1.post1
#     Uninstalling scikit-learn-1.4.1.post1:
#       Successfully uninstalled scikit-learn-1.4.1.post1
#   Attempting uninstall: sktime
#     Found existing installation: sktime 0.28.0
#     Uninstalling sktime-0.28.0:
#       Successfully uninstalled sktime-0.28.0
# Successfully installed Cython-3.0.10 Flask-3.0.3 MarkupSafe-2.1.5 Werkzeug-3.0.2 absl-py-2.1.0 adagio-0.2.4 antlr4-python3-runtime-4.11.1 appdirs-1.4.4 astunparse-1.6.3 blinker-1.7.0 click-8.1.7 cloudpickle-3.0.0 cmdstanpy-1.2.2 coreforecast-0.0.8 dash-2.16.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 dask-2024.4.1 deprecated-1.2.14 dtw-python-1.4.2 filterpy-1.4.5 flatbuffers-24.3.25 fs-2.4.16 fugue-0.8.7 fugue-sql-antlr-0.2.0 gast-0.5.4 gluonts-0.14.4 google-pasta-0.2.0 h5py-3.11.0 hmmlearn-0.3.2 holidays-0.46 importlib-metadata-7.1.0 importlib-resources-6.4.0 jinja2-3.1.3 keras-3.2.1 keras-self-attention-0.51.0 kotsu-0.3.3 lazy-loader-0.4 libclang-18.1.1 locket-1.0.0 markdown-3.6 ml-dtypes-0.3.2 mne-1.6.1 namex-0.0.7 numpy-1.25.2 opt-einsum-3.3.0 optree-0.11.0 pandas-2.0.3 partd-1.4.1 pmdarima-2.0.4 pooch-1.8.1 prophet-1.1.5 pyaml-23.12.0 pykalman-0.9.7 pyod-1.1.3 qpd-0.4.4 retrying-1.3.4 scikit-base-0.5.2 scikit-learn-1.2.2 scikit-optimize-0.10.1 scikit-posthocs-0.9.0 seasonal-0.3.1 sktime-0.20.1 sqlglot-23.10.0 stanio-0.5.0 statsforecast-1.7.4 stumpy-1.12.0 tbats-1.1.3 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-io-gcs-filesystem-0.36.0 triad-0.9.6 tsfresh-0.20.2 tslearn-0.5.3.2 utilsforecast-0.1.3 wrapt-1.16.0 xarray-2024.3.0

# %%
import pandas as pd
from sktime.transformations.series.adapters import SeriesToPanelAdapter
from sktime.transformations.series.detrend import Detrender
from sktime.transformations.series.scale import MinMaxScaler
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.compose import ForecastingPipeline
from sktime.forecasting.theta import ThetaForecaster
from sktime.datasets import load_airline
from sktime.transformations.panel.compose import TimeSeriesTransformerModel

# Load your own dataset
# df = pd.read_csv('your_dataset.csv', index_col='date_column', parse_dates=True)

# For this example, we use the airline dataset
df = load_airline()

# Define the transformer model
transformer = TimeSeriesTransformerModel(
    steps=[
        ('adapter', SeriesToPanelAdapter()),
        ('detrender', Detrender()),
        ('scaler', MinMaxScaler())
    ]
)

# Define the forecaster
forecaster = ThetaForecaster()

# Define the pipeline
pipeline = ForecastingPipeline(
    steps=[
        ('transformer', transformer),
        ('forecaster', forecaster)
    ]
)

# Split the data into train and test sets
y_train, y_test = temporal_train_test_split(df)

# Fit the pipeline to the training data
pipeline.fit(y_train)

# Make predictions on the test data
y_pred = pipeline.predict(fh=y_test.index)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[88], line 2
#       1 import pandas as pd
# ----> 2 from sktime.transformations.series.adapters import SeriesToPanelAdapter
#       3 from sktime.transformations.series.detrend import Detrender
#       4 from sktime.transformations.series.scale import MinMaxScaler
#
# ModuleNotFoundError: No module named 'sktime.transformations.series.adapters'
