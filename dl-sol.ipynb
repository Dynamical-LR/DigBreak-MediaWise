# %%
import pandas as pd

# %%
df = pd.read_excel('train/train_new.xlsx')

# %%
columns = df.columns

# %%
columns = list(columns)

# %%
columns[0] = 'Период'

# %%
columns
# Out:
# ['Период',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'KPI \nданные понедельно АлфаРМ',
#  'Unnamed: 4',
#  'KPI\nданные помесячно АлфаРМ',
#  'KPI\n данные помесячно АлфаРМ (по SKU)',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Дистрибуция (данные Альфа РМ)',
#  'выписки врачами',
#  'статистика заболеваемости',
#  'индекс цены',
#  'развитие дженериков',
#  'Unnamed: 17',
#  'Медиа ТВ \n(Моделируемый бренд)',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Медиа Диджитал \n(Моделируемый бренд)',
#  'Медиа Радио \n(Моделируемый бренд)',
#  'Unnamed: 35',
#  'Запросы Wordstat',
#  'Медиа (Конкурент 1)',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
# ...

# %%
def transform_columns():
    current_col = columns[0]
    for i in range(len(columns)):
        if 'Unnamed' in columns[i]:
            columns[i] = current_col
        else:
            current_col = columns[i]

# %%
transform_columns()

# %%
df.columns = columns

# %%
df
# Out:
#     Период  Период               Период KPI \nданные понедельно АлфаРМ  \
# 0      год  неделя           Начало нед                 Продажи, рубли
# 1     2019       1  2018-12-31 00:00:00                   41535567.339
# 2      NaN       2  2019-01-07 00:00:00                   51222286.227
# 3      NaN       3  2019-01-14 00:00:00                   57127348.908
# 4      NaN       4  2019-01-21 00:00:00                  63040990.9395
# ..     ...     ...                  ...                            ...
# 310    NaN      49  2024-12-02 00:00:00                            NaN
# 311    NaN      50  2024-12-09 00:00:00                            NaN
# 312    NaN      51  2024-12-16 00:00:00                            NaN
# 313    NaN      52  2024-12-23 00:00:00                            NaN
# 314    NaN       1  2024-12-30 00:00:00                            NaN
#
#     KPI \nданные понедельно АлфаРМ KPI\nданные помесячно АлфаРМ  \
# ...

# %%
first_row = df.iloc[0]

# %%
row = list(first_row)
new_row = [f'{columns[i]}_{row[i]}' for i in range(len(columns))]

# %%
new_row = [t.strip().replace('\n', '') for t in new_row]

# %%
df.columns = new_row

# %%
df = df[1:]

# %%
len(df.columns)
# Out:
# 147

# %%
df_new = df
df_new
# Out:
#     Период_год Период_неделя    Период_Начало нед  \
# 1         2019             1  2018-12-31 00:00:00
# 2          NaN             2  2019-01-07 00:00:00
# 3          NaN             3  2019-01-14 00:00:00
# 4          NaN             4  2019-01-21 00:00:00
# 5          NaN             5  2019-01-28 00:00:00
# ..         ...           ...                  ...
# 310        NaN            49  2024-12-02 00:00:00
# 311        NaN            50  2024-12-09 00:00:00
# 312        NaN            51  2024-12-16 00:00:00
# 313        NaN            52  2024-12-23 00:00:00
# 314        NaN             1  2024-12-30 00:00:00
#
#     KPI данные понедельно АлфаРМ_Продажи, рубли  \
# 1                                  41535567.339
# 2                                  51222286.227
# 3                                  57127348.908
# 4                                 63040990.9395
# 5                                 67336888.8675
# ..                                          ...
# ...

# %%
columns = df.columns

# %%
f_columns = [col for col in columns if 'месяч' in col]

# %%
for column in f_columns:
    df[column] = df[column].replace(0, pd.NA)
    df[column] = df[column].bfill()
# Out:
# /tmp/ipykernel_82329/82921121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].replace(0, pd.NA)
# /tmp/ipykernel_82329/82921121.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[column] = df[column].bfill()
# /tmp/ipykernel_82329/82921121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df[:244] = new_df
# Out:
# /tmp/ipykernel_82329/232616158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[:244] = new_df

# %%
df
# Out:
#     Период_год Период_неделя    Период_Начало нед  \
# 1         2019             1  2018-12-31 00:00:00
# 2         2019             2  2019-01-07 00:00:00
# 3         2019             3  2019-01-14 00:00:00
# 4         2019             4  2019-01-21 00:00:00
# 5         2019             5  2019-01-28 00:00:00
# ..         ...           ...                  ...
# 310        NaN            49  2024-12-02 00:00:00
# 311        NaN            50  2024-12-09 00:00:00
# 312        NaN            51  2024-12-16 00:00:00
# 313        NaN            52  2024-12-23 00:00:00
# 314        NaN             1  2024-12-30 00:00:00
#
#     KPI данные понедельно АлфаРМ_Продажи, рубли  \
# 1                                  41535567.339
# 2                                  51222286.227
# 3                                  57127348.908
# 4                                 63040990.9395
# 5                                 67336888.8675
# ..                                          ...
# ...

# %%
df['Период_год'] = df['Период_год'].ffill()
# Out:
# /tmp/ipykernel_82329/3911074203.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Период_год'] = df['Период_год'].ffill()
# /tmp/ipykernel_82329/3911074203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Период_год'] = df['Период_год'].ffill()

# %%
df
# Out:
#      Период_год Период_неделя    Период_Начало нед  \
# 1          2019             1  2018-12-31 00:00:00
# 2          2019             2  2019-01-07 00:00:00
# 3          2019             3  2019-01-14 00:00:00
# 4          2019             4  2019-01-21 00:00:00
# 5          2019             5  2019-01-28 00:00:00
# ..          ...           ...                  ...
# 310        2024            49  2024-12-02 00:00:00
# 311        2024            50  2024-12-09 00:00:00
# 312        2024            51  2024-12-16 00:00:00
# 313        2024            52  2024-12-23 00:00:00
# 314        2024             1  2024-12-30 00:00:00
#
#     KPI данные понедельно АлфаРМ_Продажи, рубли  \
# 1                                  41535567.339
# 2                                  51222286.227
# 3                                  57127348.908
# 4                                 63040990.9395
# 5                                 67336888.8675
# ..                                          ...
# ...

# %%
df.to_csv('dataset.csv', index=False)
